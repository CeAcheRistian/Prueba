# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4,5])

# %%
plt.plot([1,2,3,4,5], [90,2,56,11,4])

# %%
x = np.linspace(0,10,25)
y = np.linspace(0,5,25)
plt.plot(x,y)

# %%
df = pd.read_excel("netflix_titles.xlsx")
df.head(10)
# Out:
#   show_id     type     title           director  \
# 0      s1  TV Show      0.03                NaN
# 1      s2    Movie  07:19:00  Jorge Michel Grau
# 2      s3    Movie  23:59:00       Gilbert Chan
# 3      s4    Movie         9        Shane Acker
# 4      s5    Movie        21     Robert Luketic
# 5      s6  TV Show        46        Serdar Akar
# 6      s7    Movie       122    Yasir Al Yasiri
# 7      s8    Movie       187     Kevin Reynolds
# 8      s9    Movie       706      Shravan Kumar
# 9     s10    Movie      1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
plt.plot(df["release_year"][0:20], df["show_id"][0:20], "r", linewidth = 10)
plt.xlim(2000,2010)
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %%
plt.plot(df["release_year"][0:20], df["show_id"][0:20], "r", linewidth = 3, marker = "x")

# %%
plt.subplot(1,2,1) #Es una grafica de 1 fila, 2 columnas y en el sigueinte lugar, se colocara lo siguiente
plt.plot(x,y,"m")
plt.subplot(1,2,2)
plt.plot(y,x,"b")

# %%
plt.subplot(1,2,1) #Es una grafica de 1 fila, 2 columnas y en el sigueinte lugar, se colocara lo siguiente
plt.plot(df["release_year"][0:20],df["show_id"][0:20],"m")
plt.subplot(1,2,2)
plt.plot(df["show_id"][0:5],df["duration"][0:5],"b")

# %%
fg = plt.figure(figsize = (5,5), facecolor = "b")
axis = fg.add_axes([0,0.5,0.1,0.9])
axis.plot(x, y, "b")
